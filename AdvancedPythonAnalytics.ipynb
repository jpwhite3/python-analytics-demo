# %%
from __future__ import division, unicode_literals

# Silence warning messages
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import glob, json
import matplotlib.pyplot as plt
import seaborn as sb
import calendar

# Our blank DataFrame
df = pd.read_excel('./input/all_data.xls')
df['dayofweek'] = df['date'].dt.dayofweek
df['dayofweek'] = df['dayofweek'].apply(lambda x: calendar.day_name[x])
df['year'] = df['date'].dt.year
df['quarter'] = df['date'].dt.quarter
df['quarter'] = df['quarter'].apply(lambda x: "Q%s"%x)

# %%
all_data.head()
# Out:
#         sku  quantity  ext price  year quarter dayofweek             name  \
# 0  B1-20000         7     235.83  2014      Q1       Sat         Will LLC
# 1  S1-27722        11     232.32  2014      Q1       Sat    Jerde-Hilpert
# 2  B1-86481         3     107.97  2014      Q1       Sat    Jerde-Hilpert
# 3  B1-20000        23    1814.70  2014      Q1       Sat    Jerde-Hilpert
# 4  S1-06532        48    2679.36  2014      Q1       Sun  Kuhn-Gusikowski
#
#    status
# 0  bronze
# 1  bronze
# 2  bronze
# 3  bronze
# 4  silver

# %%
final_df = df[['sku', 'quantity', 'ext price','date', 'year', 'quarter', 'dayofweek', 'name', 'status']]

# %%
# %matplotlib inline
sb.set_style("whitegrid")
fig, ax = plt.subplots()
fig.set_size_inches(16, 9)
sb.stripplot(x="dayofweek", y="ext price", data=final_df, jitter=True, size=3, ax=ax)
